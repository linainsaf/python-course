# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

class SalesAnalysis:    
    def __init__(self, file_path):
        self.df = pd.read_csv(file_path, encoding='latin-1')
        
    def clean_data(self):
        # Remove rows with missing values
        self.df.dropna(inplace=True)
        
        # Remove duplicates
        self.df.drop_duplicates(inplace=True)
        
        # Convert date strings to datetime objects
        self.df['Order Date'] = pd.to_datetime(self.df['Order Date'])
        
        # Convert numerical values to appropriate data types
        self.df['Quantity'] = self.df['Quantity'].astype(int)
        self.df['Sales'] = self.df['Sales'].astype(float)
    
    def sales_by_region(self):
        plt.figure(figsize=(10,6))
        sns.barplot(x='Region', y='Quantity', data=self.df)
        plt.title('Sales by Region')
        plt.xlabel('Region')
        plt.ylabel('Quantity')
        plt.show()
        
    def sales_by_date(self, max_date = None, min_date=None):
        min_date = pd.to_datetime(min_date)
        max_date = pd.to_datetime(max_date)
        if min_date > max_date :
            return "Your dates aren't correct please enter again !"
        plt.figure(figsize=(10,6))
        if max_date and min_date:
            d = self.df[self.df['Order Date']> min_date][self.df['Order Date'] <max_date]
            sns.lineplot(x='Order Date', y='Sales', data=d)
        elif max_date : 
            sns.lineplot(x='Order Date', y='Sales', data=self.df[self.df['Order Date']<max_date])
        elif min_date:
            sns.lineplot(x='Order Date', y='Sales', data=self.df[self.df['Order Date']>min_date])
        else : 
            sns.lineplot(x='Order Date', y='Sales', data=self.df)

        plt.title('Sales by Date')
        plt.xlabel('Date')
        plt.ylabel('Sales')
        plt.show()
        
    def sales_by_category(self, limit_sales=None):
        plt.figure(figsize=(10,6))
        if limit_sales :
            sns.boxplot(x='Category', y='Sales', data=self.df[df['Sales']<limit_sales])
        else :
            sns.boxplot(x='Category', y='Sales', data=self.df)
        plt.title('Sales by Category')
        plt.xlabel('Category')
        plt.ylabel('Sales')
        plt.show()
        
    def total_revenue(self):
        return np.sum(self.df['Sales'])
        
    def average_quantity(self):
        return np.mean(self.df['Quantity'])
        
    def median_revenue(self):
        return np.median(self.df['Sales'])
        
    def total_revenue_by_region(self):
        return self.df.groupby('Region')['Sales'].sum()
    
    def average_quantity_by_region(self):
        return self.df.groupby('Region')['Quantity'].mean()
    
    def  median_revenue_by_region(self):
        return self.df.groupby('Region')['Sales'].median()

# %%
df = pd.read_csv('superstore_dataset.csv', encoding='latin-1')
df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
sl = SalesAnalysis('superstore_dataset.csv')
sl.df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
sl.clean_data()
# Out:
# /var/folders/fn/1lbn3r017dg11gg5mnymslth0000gn/T/ipykernel_8935/1300027860.py:18: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   self.df['Order Date'] = pd.to_datetime(self.df['Order Date'])

# %%
sl.df.head()
# Out:
#     Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 7    34662  CA-2011-115161 2011-01-02  3/2/2011     First Class    LC-17050
# 27   37844  CA-2011-113880 2011-01-03  5/3/2011  Standard Class    VF-21715
# 32   31454  CA-2011-104269 2011-01-03  6/3/2011    Second Class    DB-13060
# 34   39607  CA-2011-168312 2011-01-03  7/3/2011  Standard Class    GW-14605
# 36   39245  CA-2011-131009 2011-01-03  5/3/2011  Standard Class    SC-20380
#
#        Customer Name      Segment           City       State  ...  \
# 7       Liz Carlisle     Consumer  Mission Viejo  California  ...
# 27    Vicky Freymann  Home Office       Elmhurst    Illinois  ...
# 32       Dave Brooks     Consumer        Seattle  Washington  ...
# 34  Giulietta Weimer     Consumer        Houston       Texas  ...
# 36  Shahid Collister     Consumer        El Paso       Texas  ...
#
#          Product ID   Category Sub-Category  \
# 7   FUR-BO-10003966  Furniture    Bookcases
# ...

# %%
sl.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9994 entries, 7 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   City            9994 non-null   object
#  9   State           9994 non-null   object
#  10  Country         9994 non-null   object
#  11  Postal Code     9994 non-null   float64
#  12  Market          9994 non-null   object
#  13  Region          9994 non-null   object
#  14  Product ID      9994 non-null   object
#  15  Category        9994 non-null   object
#  16  Sub-Category    9994 non-null   object
# ...

# %%
sl.sales_by_region()

# %%
sl.sales_by_date(max_date = "2012-01-02", min_date="2011-01-02")
# Out:
# /var/folders/fn/1lbn3r017dg11gg5mnymslth0000gn/T/ipykernel_8935/1300027860.py:39: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   d = self.df[self.df['Order Date']> min_date][self.df['Order Date'] <max_date]

# %%
sl.sales_by_category(limit_sales=1000)
# Out:
# /var/folders/fn/1lbn3r017dg11gg5mnymslth0000gn/T/ipykernel_8935/1300027860.py:56: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.boxplot(x='Category', y='Sales', data=self.df[df['Sales']<limit_sales])

# %%
sl.total_revenue()
# Out:
# 2297200.8603

# %%
sl. average_quantity()
# Out:
# 3.789573744246548

# %%
sl.median_revenue()
# Out:
# 54.489999999999995

# %%
sl.total_revenue_by_region()
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
sl.median_revenue_by_region()
# Out:
# Region
# Central    45.980
# East       54.900
# South      54.594
# West       60.840
# Name: Sales, dtype: float64

# %%
sl.average_quantity_by_region()
# Out:
# Region
# Central    3.779595
# East       3.728230
# South      3.832716
# West       3.829535
# Name: Quantity, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

class SalesAnalysis:
    
    def __init__(self, file_path):
        self.df = pd.read_csv(file_path, encoding='latin-1')

    def clean_data(self):
        # Remove duplicates
        self.df.drop_duplicates(inplace=True)

        # Fill missing values with 0
        self.df.fillna(0, inplace=True)

        # Convert Order Date to datetime object
        self.df['Order Date'] = pd.to_datetime(self.df['Order Date'])

        # Convert Quantity to int
        self.df['Quantity'] = self.df['Quantity'].astype(int)

        # Convert Sales to float
        self.df['Sales'] = self.df['Sales'].astype(float)

    def total_revenue_by_year_region(self):
        return self.df.groupby(['Order Date', 'Region'])['Sales'].sum().reset_index()

    def highest_sales_revenue(self):
        return self.df.groupby(['Order Date', 'Region'])['Sales'].sum().idxmax()

    def average_sales_revenue_per_month(self):
        return self.df.groupby(['Region', pd.Grouper(key='Order Date', freq='M')])['Sales'].mean().reset_index()

    def highest_sales_category(self):
        return self.df.groupby(['Category'])['Sales'].sum().idxmax()

    def percentage_contribution(self):
        return self.df.groupby(['Category'])['Sales'].sum() / self.df['Sales'].sum() * 100

    def visualize_total_revenue(self):
        total_revenue = self.total_revenue_by_year_region()
        plt.figure(figsize=(12, 8))
        sns.barplot(x='Order Date', y='Sales', hue='Region', data=total_revenue)
        plt.title('Total Revenue by Year and Region')
        plt.xlabel('Year')
        plt.ylabel('Revenue')
        plt.show()

    def visualize_average_sales_revenue(self):
        average_sales = self.average_sales_revenue_per_month()
        plt.figure(figsize=(12, 8))
        sns.lineplot(x='Order Date', y='Sales', hue='Region', data=average_sales)
        plt.title('Monthly Average Sales Revenue by Region')
        plt.xlabel('Month')
        plt.ylabel('Average Sales Revenue')
        plt.show()

    def visualize_percentage_contribution(self):
        percentage = self.percentage_contribution()
        plt.figure(figsize=(12, 8))
        plt.pie(percentage, labels=percentage.index, autopct='%1.1f%%')
        plt.title('Percentage Contribution of Each Product Category to Total Revenue')
        plt.show()

    def statistical_analysis(self):
        return self.df.groupby(['Region'])['Sales'].agg([np.mean, np.median, np.std])
    
    def generate_report(self):
        print("\nSALES REPORT")
        print("============")
        print("Total Revenue by Year and Region:\n", self.total_revenue_by_year_region())
        print("\nYear and Region with Highest Sales Revenue:\n", self.highest_sales_revenue())
        print("\nAverage Sales Revenue per Month by Region:\n", self.average_sales_revenue_per_month())
        print("\nProduct Category with Highest Sales Revenue:\n", self.highest_sales_category())
        print("\nPercentage Contribution of Product Categories to Total Revenue:\n", self.percentage_contribution())
        
        #self.visualize_total_revenue()
        self.visualize_average_sales_revenue()
        self.visualize_percentage_contribution()
        
        print("\nStatistical Analysis of Sales Revenue by Region:")
        sales_stats = self.statistical_analysis()
        for index, row in sales_stats.iterrows():
            region = index
            print(f"\n{region}:")
            print("Mean:", row["mean"])
            print("Median:", row["median"])
            print("Standard Deviation:", row["std"])
        
    def save_clean_data(self, file_path):
        self.df.to_csv(file_path, index=False)

    def save_figure(self, fig, file_path):
        fig.savefig(file_path)

# %%
sl = SalesAnalysis('superstore_dataset.csv')
sl.df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
sl.clean_data()
# Out:
# /var/folders/fn/1lbn3r017dg11gg5mnymslth0000gn/T/ipykernel_87998/2096680884.py:19: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   self.df['Order Date'] = pd.to_datetime(self.df['Order Date'])

# %%
sl.df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040 2011-01-01  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883 2011-01-01  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220 2011-01-01  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632 2011-01-01  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883 2011-01-01  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
sl.total_revenue_by_year_region()
# Out:
#       Order Date          Region      Sales
# 0     2011-01-01          Africa   408.3000
# 1     2011-01-01            EMEA    66.1200
# 2     2011-01-01           North    44.8650
# 3     2011-01-01         Oceania   289.2780
# 4     2011-01-02          Africa   206.4000
# ...          ...             ...        ...
# 11023 2014-12-31           North  1483.1300
# 11024 2014-12-31      North Asia   658.5000
# 11025 2014-12-31           South  2284.7260
# 11026 2014-12-31  Southeast Asia  3493.8963
# 11027 2014-12-31            West    37.6480
#
# [11028 rows x 3 columns]

# %%
sl.highest_sales_revenue()
# Out:
# (Timestamp('2011-03-18 00:00:00'), 'South')

# %%
sl.average_sales_revenue_per_month()
# Out:
#      Region Order Date       Sales
# 0    Africa 2011-01-31  140.395600
# 1    Africa 2011-02-28  143.008266
# 2    Africa 2011-03-31  112.949827
# 3    Africa 2011-04-30  148.402421
# 4    Africa 2011-05-31  130.089000
# ..      ...        ...         ...
# 619    West 2014-08-31  281.562786
# 620    West 2014-09-30  207.246808
# 621    West 2014-10-31  230.603435
# 622    West 2014-11-30  184.970083
# 623    West 2014-12-31  186.454452
#
# [624 rows x 3 columns]

# %%
sl.highest_sales_category()
# Out:
# 'Technology'

# %%
sl.percentage_contribution()
# Out:
# Category
# Furniture          32.516303
# Office Supplies    29.955069
# Technology         37.528628
# Name: Sales, dtype: float64

# %%
sl.visualize_total_revenue()

# %%
sl.visualize_average_sales_revenue()

# %%
sl.visualize_percentage_contribution()

# %%
sl.statistical_analysis()
# Out:
#                       mean     median         std
# Region
# Africa          170.868370   52.44000  359.395167
# Canada          174.292109   60.03000  332.848799
# Caribbean       191.882166   77.49000  302.953029
# Central         253.872674   95.06948  479.369521
# Central Asia    367.591097  136.60500  624.287769
# EMEA            160.302508   51.78000  327.192343
# East            238.336110   54.90000  620.712652
# North           260.849656   96.78000  452.997471
# North Asia      362.835663  144.90000  585.376411
# Oceania         315.510356  118.22400  546.849341
# South           240.919043   86.04000  528.861212
# Southeast Asia  282.653617  104.70450  470.877449
# West            226.493233   60.84000  524.876877

# %%
sl.generate_report()
# Out:
# SALES REPORT
# ...
# Total Revenue by Year and Region:
#        Order Date          Region      Sales
# 0     2011-01-01          Africa   408.3000
# 1     2011-01-01            EMEA    66.1200
# 2     2011-01-01           North    44.8650
# 3     2011-01-01         Oceania   289.2780
# 4     2011-01-02          Africa   206.4000
# ...          ...             ...        ...
# 11023 2014-12-31           North  1483.1300
# 11024 2014-12-31      North Asia   658.5000
# 11025 2014-12-31           South  2284.7260
# 11026 2014-12-31  Southeast Asia  3493.8963
# 11027 2014-12-31            West    37.6480
#
# [11028 rows x 3 columns]
#
# Year and Region with Highest Sales Revenue:
#  (Timestamp('2011-03-18 00:00:00'), 'South')
#
# Average Sales Revenue per Month by Region:
#       Region Order Date       Sales
# 0    Africa 2011-01-31  140.395600
# 1    Africa 2011-02-28  143.008266
# 2    Africa 2011-03-31  112.949827
# 3    Africa 2011-04-30  148.402421
# 4    Africa 2011-05-31  130.089000
# ...

# %%
class SalesAnalysis:
    def __init__(self, file_path):
        self.df = pd.read_csv(file_path, encoding='latin-1')
    
    def clean_data(self, drop_duplicates=True, fillna=True, date_format='%m/%d/%Y', 
                   convert_types={'Order Date': 'datetime64[ns]', 'Quantity': int, 'Sales': float}):
        """
        This method cleans the data by handling missing values, duplicates, and converting data types.
        """
        if drop_duplicates:
            self.df.drop_duplicates(inplace=True)
        if fillna:
            # Fill missing values with 0
            self.df.fillna(0, inplace=True)
        self.df = self.df.astype(convert_types)
        self.df['Order Date'] = pd.to_datetime(self.df['Order Date'], format=date_format)
    
    def filter_by_date(self, start_date=None, end_date=None):
        """
        This method filters the data by date, keeping only rows where the Order Date column is between start_date and end_date.
        """
        if start_date is not None:
            self.df = self.df[self.df['Order Date'] >= pd.to_datetime(start_date)]
        if end_date is not None:
            self.df = self.df[self.df['Order Date'] <= pd.to_datetime(end_date)]
            
    def sales_by_category(self, category=None):
        if category is None:
            sales_data = self.df.groupby('Category')['Sales'].sum()
        else:
            sales_data = self.df[self.df['Category'] == category].groupby('Category')['Sales'].sum()
        return sales_data
    
    def sales_by_region(self, region=None):
        if region is None:
            sales_data = self.df.groupby('Region')['Sales'].sum()
        else:
            sales_data = self.df[self.df['Region'] == region].groupby('Region')['Sales'].sum()
        return sales_data
    
    def sales_by_subcategory(self, subcategory=None):
        if subcategory is None:
            sales_data = self.df.groupby('Sub-Category')['Sales'].sum()
        else:
            sales_data = self.df[self.df['Sub-Category'] == subcategory].groupby('Sub-Category')['Sales'].sum()
        return sales_data
    
    def quantity_by_category(self, category=None):
        if category is None:
            quantity_data = self.df.groupby('Category')['Quantity'].sum()
        else:
            quantity_data = self.df[self.df['Category'] == category].groupby('Category')['Quantity'].sum()
        return quantity_data
    
    def shipping_cost_by_region(self, region=None):
        if region is None:
            shipping_data = self.df.groupby('Region')['Shipping Cost'].sum()
        else:
            shipping_data = self.df[self.df['Region'] == region].groupby('Region')['Shipping Cost'].sum()
        return shipping_data
    
    def discount_by_subcategory(self, subcategory=None):
        if subcategory is None:
            discount_data = self.df.groupby('Sub-Category')['Discount'].mean()
        else:
            discount_data = self.df[self.df['Sub-Category'] == subcategory].groupby('Sub-Category')['Discount'].mean()
        return discount_data
    
    def total_sales(self, category=None, region=None):
        if category and region:
            return self.df[(self.df['Category'] == category) & (self.df['Region'] == region)]['Sales'].sum()
        elif category:
            return self.df[self.df['Category'] == category]['Sales'].sum()
        elif region:
            return self.df[self.df['Region'] == region]['Sales'].sum()
        else:
            return self.df['Sales'].sum()
        
    def total_profit(self, category=None, region=None):
        if category and region:
            return self.df[(self.df['Category'] == category) & (self.df['Region'] == region)]['Profit'].sum()
        elif category:
            return self.df[self.df['Category'] == category]['Profit'].sum()
        elif region:
            return self.df[self.df['Region'] == region]['Profit'].sum()
        else:
            return self.df['Profit'].sum()
        
    def average_sales(self, category=None, region=None):
        if category and region:
            return self.df[(self.df['Category'] == category) & (self.df['Region'] == region)]['Sales'].mean()
        elif category:
            return self.df[self.df['Category'] == category]['Sales'].mean()
        elif region:
            return self.df[self.df['Region'] == region]['Sales'].mean()
        else:
            return self.df['Sales'].mean()
        
    def average_profit(self, category=None, region=None):
        if category and region:
            return self.df[(self.df['Category'] == category) & (self.df['Region'] == region)]['Profit'].mean()
        elif category:
            return self.df[self.df['Category'] == category]['Profit'].mean()
        elif region:
            return self.df[self.df['Region'] == region]['Profit'].mean()
        else:
            return self.df['Profit'].mean()
        
    def top_n_sales_categories(self, n=5):
        df_sales_category = self.df.groupby('Category')['Sales'].sum().reset_index().sort_values('Sales', ascending=False).head(n)
        return df_sales_category
    
    def worst_n_profit_margin_regions(self, n=5):
        df_profit_region = self.df.groupby('Region')['Profit'].sum().reset_index()
        df_sales_region = self.df.groupby('Region')['Sales'].sum().reset_index()
        df_merged = pd.merge(df_profit_region, df_sales_region, on='Region', how='inner')
        df_merged['Profit Margin'] = df_merged['Profit'] / df_merged['Sales'] * 100
        df_worst_n = df_merged.sort_values('Profit Margin', ascending=True).head(n)
        return df_worst_n
    
    def total_revenue_by_year_region(self):
        df_year_region_revenue = self.df.groupby(['Year', 'Region'])['Sales'].sum().reset_index()
        return df_year_region_revenue
    
    def highest_sales_year_region(self):
        df_year_region_revenue = self.df.groupby(['Year', 'Region'])['Sales'].sum().reset_index()
        max_revenue = df_year_region_revenue['Sales'].max()
        year_region = df_year_region_revenue[df_year_region_revenue['Sales'] == max_revenue].iloc[0]
        return year_region
    
    def average_sales_revenue_per_month_region(self):
        df_sales_month_region = self.df.groupby(['Region', pd.Grouper(key='Order Date', freq='M')])['Sales'].sum().reset_index()
        df_average_sales = df_sales_month_region.groupby('Region')['Sales'].mean().reset_index()
        return df_average_sales
    
    def highest_sales_category(self):
        df_sales_category = self.df.groupby('Category')['Sales'].sum().reset_index()
        max_sales = df_sales_category['Sales'].max()
        category = df_sales_category[df_sales_category['Sales'] == max_sales].iloc[0]
        return category
    
    def category_sales_contribution(self):
        df_sales_category = self.df.groupby('Category')['Sales'].sum().reset_index()
        total_sales = df_sales_category['Sales'].sum()
        df_sales_category['Sales Contribution'] = df_sales_category['Sales'] / total_sales * 100
        return df_sales_category
    
    def visualize_sales_by_category(self, category=None):
        data = self.sales_by_category(category)
        sns.barplot(x='Category', y='Sales', data=data)
        plt.show()

    def visualize_sales_by_region(self, region=None):
        data = self.sales_by_region(region)
        sns.barplot(x='Region', y='Sales', data=data)
        plt.show()

    def visualize_sales_by_subcategory(self, category=None):
        data = self.quantity_by_category(category)
        sns.barplot(x='Category', y='Quantity', data=data)
        plt.show()

    def visualize_quantity_by_category(self, category=None):
        data = self.quantity_by_category(category)
        sns.barplot(x='Category', y='Quantity', data=data)
        plt.show()

    def visualize_shipping_cost_by_region(self, region=None):
        data = self.shipping_cost_by_region(region)
        sns.barplot(x='Region', y='Shipping Cost', data=data)
        plt.show()

    def visualize_discount_by_subcategory(self, subcategory=None):
        data = self.discount_by_subcategory(subcategory)
        sns.barplot(x='Sub-Category', y='Discount', data=data)
        plt.show()

    def visualize_yearly_avg_sales_region(self):
        data = self.df.groupby(['Order Year', 'Region'])['Sales'].mean().reset_index()
        sns.lineplot(x='Order Year', y='Sales', hue='Region', data=data)
        plt.show()

    def visualize_category_contribution(self):
        data = self.category_contribution_to_total_sales()
        plt.pie(data['Total Sales'], labels=data['Category'], autopct='%1.1f%%')
        plt.show()
    
    def generate_report(self, start_date=None, end_date=None):
        # filter data by date range if start and/or end date are provided
        if start_date and end_date:
            self.filter_by_date(start_date=start_date, end_date=end_date)
        
        # calculate summary statistics
        total_sales = self.total_sales()
        total_profit = self.total_profit()
        avg_sales = self.average_sales()
        avg_profit = self.average_profit()
        
        # find top sales categories and worst performing regions
        top_categories = self.top_n_sales_categories(n=5)
        worst_regions = self.worst_performing_regions(n=5)
        
        # calculate total revenue by year and region
        revenue_by_year_region = self.total_revenue_by_year_region()
        
        # find year and region with highest sales revenue
        highest_sales_year, highest_sales_region = self.highest_sales_year_region()
        
        # calculate average sales revenue per month by region
        avg_sales_per_month = self.average_sales_revenue_per_month()
        
        # find product category with highest sales revenue
        highest_sales_category = self.highest_sales_category()
        
        # calculate percentage contribution of each product category to total sales revenue
        category_contribution = self.category_contribution()
        
        # visualize data
        self.visualize_sales_by_category()
        self.visualize_sales_by_region()
        self.visualize_sales_by_subcategory()
        self.visualize_quantity_by_category()
        self.visualize_shipping_cost_by_region()
        self.visualize_discount_by_subcategory()
        self.visualize_yearly_avg_sales_region()
        self.visualize_category_contribution()
        
        # Save cleaned data to new CSV file
        self.df.to_csv('cleaned_data.csv', index=False)
        
        # Save figures
        plt.savefig('sales_by_category.png')
        plt.savefig('sales_by_region.png')
        
        # create report
        report = f"Sales Analysis Report\n\nDate Range: {start_date} to {end_date}\n\n"
        report += f"Total Sales: {total_sales}\nTotal Profit: {total_profit}\nAverage Sales: {avg_sales}\nAverage Profit: {avg_profit}\n\n"
        report += f"Top Sales Categories:\n{top_categories}\n\n"
        report += f"Worst Performing Regions:\n{worst_regions}\n\n"
        report += f"Total Revenue by Year and Region:\n{revenue_by_year_region}\n\n"
        report += f"Highest Sales Year and Region: {highest_sales_year}, {highest_sales_region}\n\n"
        report += f"Average Sales Revenue per Month by Region:\n{avg_sales_per_month}\n\n"
        report += f"Highest Sales Category: {highest_sales_category}\n\n"
        report += f"Category Contribution to Total Sales Revenue:\n{category_contribution}"
        
        return report

# %%
sl = SalesAnalysis('superstore_dataset.csv')
sl.df
# Out:
#        Row ID         Order ID  Order Date Ship Date       Ship Mode  \
# 0       42433     AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1       22253    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2       48883     HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3       11731  IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4       22255    IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...       ...              ...         ...       ...             ...
# 51285   32593   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286   47594     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287    8857   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288    6852   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   36388   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#       Customer ID     Customer Name      Segment         City  \
# 0        TB-11280   Toby Braunhardt     Consumer  Constantine
# ...

# %%
sl.clean_data()
sl.filter_by_date("1/1/2011", "1/1/2014")
# Out:
# /var/folders/fn/1lbn3r017dg11gg5mnymslth0000gn/T/ipykernel_87998/3383245182.py:15: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   self.df = self.df.astype(convert_types)

# %%
sl.df.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040 2011-01-01  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883 2011-01-01  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220 2011-01-01  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632 2011-01-01  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883 2011-01-01  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
sl.sales_by_category()
# Out:
# Category
# Furniture          2.732925e+06
# Office Supplies    2.482768e+06
# Technology         3.130557e+06
# Name: Sales, dtype: float64

# %%
sl.sales_by_region()
# Out:
# Region
# Africa            5.009039e+05
# Canada            4.376706e+04
# Caribbean         2.187893e+05
# Central           1.884519e+06
# Central Asia      4.936863e+05
# EMEA              5.046634e+05
# East              4.656983e+05
# North             8.190018e+05
# North Asia        5.837893e+05
# Oceania           7.388043e+05
# South             1.055943e+06
# Southeast Asia    5.613550e+05
# West              4.753295e+05
# Name: Sales, dtype: float64

# %%
sl.sales_by_subcategory()
# Out:
# Sub-Category
# Accessories    4.957489e+05
# Appliances     6.512775e+05
# Art            2.448368e+05
# Binders        3.017415e+05
# Bookcases      9.533755e+05
# Chairs         1.008303e+06
# Copiers        9.590514e+05
# Envelopes      1.170823e+05
# Fasteners      5.468315e+04
# Furnishings    2.576649e+05
# Labels         4.760375e+04
# Machines       5.203045e+05
# Paper          1.647144e+05
# Phones         1.155452e+06
# Storage        7.439529e+05
# Supplies       1.568752e+05
# Tables         5.135815e+05
# Name: Sales, dtype: float64

# %%
sl.quantity_by_category()
# Out:
# Category
# Furniture          23289
# Office Supplies    71319
# Technology         23159
# Name: Quantity, dtype: int64

# %%
sl.shipping_cost_by_region()
# Out:
# Region
# Africa             58082.78
# Canada              4907.23
# Caribbean          24146.76
# Central           195497.42
# Central Asia       49683.05
# EMEA               55039.71
# East               49889.89
# North              85051.11
# North Asia         67022.40
# Oceania            82202.99
# South             111547.97
# Southeast Asia     59381.65
# West               50250.03
# Name: Shipping Cost, dtype: float64

# %%
sl.discount_by_subcategory()
# Out:
# Sub-Category
# Accessories    0.122106
# Appliances     0.143030
# Art            0.114064
# Binders        0.177629
# Bookcases      0.153374
# Chairs         0.163447
# Copiers        0.118161
# Envelopes      0.128259
# Fasteners      0.135167
# Furnishings    0.152921
# Labels         0.120223
# Machines       0.173918
# Paper          0.111299
# Phones         0.147559
# Storage        0.139967
# Supplies       0.125720
# Tables         0.290491
# Name: Discount, dtype: float64

# %%
sl.total_sales()
# Out:
# 8346250.0738200005

# %%
sl.total_profit()
# Out:
# 963454.71082

# %%
sl.average_sales()
# Out:
# 247.05473385489745

# %%
sl.average_profit()
# Out:
# 28.51892107924104

# %%
sl. top_n_sales_categories(2)
# Out:
#      Category         Sales
# 2  Technology  3.130557e+06
# 0   Furniture  2.732925e+06

# %%
sl.worst_n_profit_margin_regions(6)
# Out:
#             Region        Profit         Sales  Profit Margin
# 11  Southeast Asia    9147.32670  5.613550e+05       1.629508
# 5             EMEA   21330.40800  5.046634e+05       4.226660
# 10           South   88634.70096  1.055943e+06       8.393890
# 0           Africa   49575.50100  5.009039e+05       9.897209
# 2        Caribbean   22038.70524  2.187893e+05      10.073027
# 3          Central  213595.01052  1.884519e+06      11.334194

# %%
sl.total_revenue_by_year_region()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 sl.total_revenue_by_year_region()
#
# Cell In [14], line 120, in SalesAnalysis.total_revenue_by_year_region(self)
#     119 def total_revenue_by_year_region(self):
# --> 120     df_year_region_revenue = self.df.groupby(['Year', 'Region'])['Sales'].sum().reset_index()
#     121     return df_year_region_revenue
#
# File /opt/homebrew/Cellar/jupyterlab/3.4.7/libexec/lib/python3.10/site-packages/pandas/core/frame.py:8392, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8389     raise TypeError("You have to supply one of 'by' and 'level'")
#    8390 axis = self._get_axis_number(axis)
# -> 8392 return DataFrameGroupBy(
#    8393     obj=self,
#    8394     keys=by,
#    8395     axis=axis,
#    8396     level=level,
#    8397     as_index=as_index,
# ...
